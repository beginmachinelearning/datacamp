# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
election_data=pd.read_csv("data/2008_swing_states.csv")

# %%
sns.set
_=sns.swarmplot(x='state', y='dem_share',data=election_data)
_=plt.xlabel("State")
_=plt.ylabel("Votes for democrats")
plt.show()

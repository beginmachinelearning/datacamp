# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
election_data=pd.read_csv("data/2008_swing_states.csv")

# %%
election_data
# Out:
#     state              county  total_votes  dem_votes  rep_votes  dem_share
# 0      PA         Erie County       127691      75775      50351      60.08
# 1      PA     Bradford County        25787      10306      15057      40.64
# 2      PA        Tioga County        17984       6390      11326      36.07
# 3      PA       McKean County        15947       6465       9224      41.21
# 4      PA       Potter County         7507       2300       5109      31.04
# 5      PA        Wayne County        22835       9892      12702      43.78
# 6      PA  Susquehanna County        19286       8381      10633      44.08
# 7      PA       Warren County        18517       8537       9685      46.85
# 8      OH    Ashtabula County        44874      25027      18949      56.94
# 9      OH         Lake County       121335      60155      59142      50.46
# 10     PA     Crawford County        38134      16780      20750      44.71
# ...

# %%
_=plt.hist(election_data['dem_share'])
_=plt.xlabel("Votes for democrats")
_=plt.ylabel("Number of counties")
plt.show()

# %%
_=plt.hist(election_data['dem_share'], bins=[10,30, 50, 70, 90])
_=plt.xlabel("Votes for democrats")
_=plt.ylabel("Number of counties")
plt.show()

# %%
_=plt.hist(election_data['dem_share'], bins=20)
_=plt.xlabel("Votes for democrats")
_=plt.ylabel("Number of counties")
plt.show()

# %%
import seaborn as sns
sns.set()
_=plt.hist(election_data['dem_share'], bins=20)
_=plt.xlabel("Votes for democrats")
_=plt.ylabel("Number of counties")
plt.show()
